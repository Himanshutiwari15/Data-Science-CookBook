# %% [markdown]
# # **Pandas-पुस्तकम्:**

# %% [markdown]
# Note: CSV files can be downloaded from below link,
#
# https://bitbucket.org/pythondsp/pandasguide/downloads/

# %%
import pandas as pd

# %% [markdown]
# ‘cast.csv’ file has five columns which store the title of movie,
# releasing year, star-casts, type(actor/actress), characters and ratings for actors, as shown below,

# %%
casts = pd.read_csv('cast.csv', index_col = None)
casts.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# The ‘titles.csv’ file contains the list
# of movies with the releasing year;

# %%
titles = pd.read_csv('titles.csv', index_col=None)
titles.tail()
# Out:
#                       title  year
# 49995                 Rebel  1970
# 49996               Suzanne  1996
# 49997                 Bomba  2013
# 49998  Aao Jao Ghar Tumhara  1984
# 49999            Mrs. Munck  1995

# %% [markdown]
# - read_csv : read the data from the csv file.
# - index_col = None : there is no index i.e. first column is data
# - head() : show only first five elements of the DataFrame
# - tail() : show only last five elements of the DataFrame

# %% [markdown]
# - len : ‘len’ commmand can be used to see the total number of rows in the file,

# %%
len(titles)
# Out:
# 50000

# %%
t = titles['title']
t
# Out:
# 0                 The Rising Son
# 1        The Thousand Plane Raid
# 2               Crucea de piatra
# 3                        Country
# 4                     Gaiking II
#                   ...
# 49995                      Rebel
# 49996                    Suzanne
# 49997                      Bomba
# 49998       Aao Jao Ghar Tumhara
# 49999                 Mrs. Munck
# Name: title, Length: 50000, dtype: object

# %%
type(t)
# Out:
# pandas.core.series.Series

# %%
t.iloc[0]
# Out:
# 'The Rising Son'

# %%
after85 = titles[titles['year'] > 1985 ]
after85
# Out:
#                   title  year
# 0        The Rising Son  1990
# 2      Crucea de piatra  1993
# 3               Country  2000
# 4            Gaiking II  2011
# 5           Medusa (IV)  2015
# ...                 ...   ...
# 49990           Junebug  2005
# 49993    Corruption.Gov  2010
# 49996           Suzanne  1996
# 49997             Bomba  2013
# 49999        Mrs. Munck  1995
#
# [29814 rows x 2 columns]

# %% [markdown]
# Note: When we pass the boolean results to DataFrame, then panda will show all the results which corresponds
# to True (rather than displaying True and False), as shown in above code. Further, ‘& (and)’ and ‘| (or)’ can be
# used for joining two conditions as shown below,

# %%
t = titles[(titles.year > 1900) & ( titles.year < 2000)]
t
# Out:
#                            title  year
# 0                 The Rising Son  1990
# 1        The Thousand Plane Raid  1969
# 2               Crucea de piatra  1993
# 7             Alex in Wonderland  1970
# 12      Poka Makorer Ghar Bosoti  1996
# ...                          ...   ...
# 49994  Lille Fridolf blir morfar  1957
# 49995                      Rebel  1970
# 49996                    Suzanne  1996
# 49998       Aao Jao Ghar Tumhara  1984
# 49999                 Mrs. Munck  1995
#
# [26884 rows x 2 columns]

# %% [markdown]
# To sort the data by values, the ‘sort_value’ option can be used. In below code, data is sorted by year now,

# %%
t = t.sort_values('year')
t
# Out:
#                                     title  year
# 32978                             Valsons  1905
# 28453  The Joe Gans-Battling Nelson Fight  1906
# 47877                          Salome Mad  1909
# 1382                    O Nono Mandamento  1909
# 11532                        La Chicanera  1909
# ...                                   ...   ...
# 39048                               Metal  1999
# 21077                    Mickey Blue Eyes  1999
# 2934              The Thomas Crown Affair  1999
# 20977           Ang kabit ni Mrs. Montero  1999
# 23489                          Idol Hands  1999
#
# [26884 rows x 2 columns]

# %% [markdown]
# Note that, various columns may contains no values, which are usually filled as NaN. For example, rows 3-4 of casts
# are NaN as shown below

# %%
casts.iloc[3:5]
# Out:
#                   title  year     name   type                character   n
# 3  Secret in Their Eyes  2015  $hutter  actor          2002 Dodger Fan NaN
# 4            Steve Jobs  2015  $hutter  actor  1988 Opera House Patron NaN

# %% [markdown]
# These null values can be easily selected, unselected or contents can be replaced by any other values e.g. empty
# strings or 0 etc. Various examples of null values are shown in this section.

# %% [markdown]
# - ‘isnull’ command returns the true value if any row of has null values. Since the rows 3-4 has NaN value,
# therefore, these are displayed as True.

# %%
c = casts
c.isnull()
# Out:
#        title   year   name   type  character      n
# 0      False  False  False  False      False  False
# 1      False  False  False  False      False  False
# 2      False  False  False  False      False  False
# 3      False  False  False  False      False   True
# 4      False  False  False  False      False   True
# ...      ...    ...    ...    ...        ...    ...
# 74996  False  False  False  False      False  False
# 74997  False  False  False  False      False   True
# 74998  False  False  False  False      False  False
# 74999  False  False  False  False      False   True
# 75000  False  False  False  False      False  False
#
# [75001 rows x 6 columns]

# %% [markdown]
# - ‘notnull’ is opposite of isnull, it returns true for not null values,

# %%
c.notnull()
# Out:
#        title  year  name  type  character      n
# 0       True  True  True  True       True   True
# 1       True  True  True  True       True   True
# 2       True  True  True  True       True   True
# 3       True  True  True  True       True  False
# 4       True  True  True  True       True  False
# ...      ...   ...   ...   ...        ...    ...
# 74996   True  True  True  True       True   True
# 74997   True  True  True  True       True  False
# 74998   True  True  True  True       True   True
# 74999   True  True  True  True       True  False
# 75000   True  True  True  True       True   True
#
# [75001 rows x 6 columns]

# %%
c[(c.n.isnull())]
# Out:
#                         title  year                        name     type  \
# 3        Secret in Their Eyes  2015                     $hutter    actor
# 4                  Steve Jobs  2015                     $hutter    actor
# 5      Straight Outta Compton  2015                     $hutter    actor
# 6      Straight Outta Compton  2015                     $hutter    actor
# 7              For Thy Love 2  2009                Bee Moe $lim    actor
# ...                       ...   ...                         ...      ...
# 74984                    Ovum  2015  Christina Rosas Anastasiou  actress
# 74985                  7 avlu  2009         Evmorfia Anastasiou  actress
# 74993     I teliki apopliromi  2013         Mara Anastasopoulou  actress
# 74997       The Magician King  2004       Tiannah Anastassiades  actress
# 74999              Toxic Tutu  2016             Zoe Anastassiou  actress
#
#                            character   n
# 3                    2002 Dodger Fan NaN
# 4            1988 Opera House Patron NaN
# 5                        Club Patron NaN
# 6                            Dopeman NaN
# 7                             Thug 1 NaN
# ...                              ...  ..
# 74984  Fertility Clinic Receptionist NaN
# 74985                          Eleni NaN
# 74993                Marina's friend NaN
# 74997        Unicycle Race Attendant NaN
# 74999              Demon of Toxicity NaN
#
# [28966 rows x 6 columns]

# %% [markdown]
# - NaN values can be fill by using fillna, ffill(forward fill), and bfill(backward fill) etc. In below code,
# ‘NaN’ values are replace by NA.

# %%
c_fill = c[c.n.isnull()].fillna('NA')
c_fill
# Out:
#                         title  year                        name     type  \
# 3        Secret in Their Eyes  2015                     $hutter    actor
# 4                  Steve Jobs  2015                     $hutter    actor
# 5      Straight Outta Compton  2015                     $hutter    actor
# 6      Straight Outta Compton  2015                     $hutter    actor
# 7              For Thy Love 2  2009                Bee Moe $lim    actor
# ...                       ...   ...                         ...      ...
# 74984                    Ovum  2015  Christina Rosas Anastasiou  actress
# 74985                  7 avlu  2009         Evmorfia Anastasiou  actress
# 74993     I teliki apopliromi  2013         Mara Anastasopoulou  actress
# 74997       The Magician King  2004       Tiannah Anastassiades  actress
# 74999              Toxic Tutu  2016             Zoe Anastassiou  actress
#
#                            character   n
# 3                    2002 Dodger Fan  NA
# 4            1988 Opera House Patron  NA
# 5                        Club Patron  NA
# 6                            Dopeman  NA
# 7                             Thug 1  NA
# ...                              ...  ..
# 74984  Fertility Clinic Receptionist  NA
# 74985                          Eleni  NA
# 74993                Marina's friend  NA
# 74997        Unicycle Race Attendant  NA
# 74999              Demon of Toxicity  NA
#
# [28966 rows x 6 columns]

# %%
t = titles[titles['title'] == 'Maa']
t
# Out:
#       title  year
# 38880   Maa  1968

# %%
t = titles[titles['title'].str.startswith('Maa')]
t
# Out:
#                            title  year
# 19              Maa Durga Shakti  1999
# 334                   Maarek hob  2004
# 3046               Maa Aur Mamta  1970
# 6304            Maampazhakkaalam  2004
# 7470           Maa Vaibhav Laxmi  1989
# 7933   Maa Kande Aaji Puate Pain  2002
# 17197              Maa al-Khatar  2016
# 21537      Maayadhaari Krishnudu  1980
# 23478                   Maanikya  2014
# 23807               Maa O Mamata  1990
# 24555                  Maadadayo  1993
# 25083                Maathi Yosi  2010
# 27451   Maang naam gwan sei deoi  2011
# 31890   Maanasaandarapetta Yezdi  2016
# 32698                   Maa Beti  1986
# 33290         Maa Mate Shakti De  1990
# 35656                      Maaro  2011
# 36001                  Maaveeran  1986
# 36061               Maan Marjada  1991
# 38592         Maata Vaishno Devi  1971
# 38880                        Maa  1968
# 38942                 MaasMurder  2017
# 42291           Maanasa Sarovara  1982
# 42463              Maa Dasha Maa  1987
# 43448                 Maa Balaji  1999
# 45292              Maa Da Laadla  1969
# 48758        Maa Inti Adapaduchu  1996
# 48865                  Maa Kasam  1999

# %% [markdown]
# Total number of occurrences can be counted using ‘value_counts()’ option. In following code, total number of
# movies are displayed base on years.

# %%
titles.year.value_counts()
# Out:
# 2016    2363
# 2017    2138
# 2015    1849
# 2014    1701
# 2013    1609
#         ...
# 1900       2
# 2024       1
# 1906       1
# 1905       1
# 2023       1
# Name: year, Length: 119, dtype: int64

# %% [markdown]
# Pandas supports the matplotlib library and can be used to plot the data as well. In previous section, the total
# numbers of movies/year were filtered out from the DataFrame. In the below code, those values are saved in new
# DataFrame and then plotted using panda,

# %%
import matplotlib.pyplot as plt

# %%
t = titles
p = t.year.value_counts()
p.plot()
plt.show()

# %% [markdown]
# It’s better to sort the years (i.e. index) first and then plot the data as below. Here, the plot shows that number
# of movies are increasing every year.

# %%
p.sort_index().plot()
plt.show()

# %% [markdown]
# Now, the graph provide some useful information i.e. number of movies are increasing each year.
